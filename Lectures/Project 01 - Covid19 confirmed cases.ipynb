# %% [markdown]
# # <center> Project 01: Covid19 Data Analysis<br> ---------------------------------------------- <center>

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
os.listdir()
# Out:
# ['time_series_covid19_confirmed_global.csv',
#  '5. Matplotlib.ipynb',
#  'survey_results_public.csv',
#  'world-happiness-report-2021.csv',
#  '.DS_Store',
#  'P_Data_Extract_From_World_Development_Indicators.xlsx',
#  'Project 01 - Covid19 confirmed cases.ipynb',
#  '1. Introduction to Python (Data Structure).ipynb',
#  'GDP per capita ppp 2021.xlsx',
#  'Real GDP Growth (IMF).xlsx',
#  '3. Functions.ipynb',
#  'README.md',
#  '6. Pandas 01.ipynb',
#  '2. Control flow (Loops).ipynb',
#  '7. Pandas 02.ipynb',
#  'Human development index (HDI).xlsx',
#  '.ipynb_checkpoints',
#  'test_1.jpg',
#  'Iran GDP growth 1 IMF.jpg',
#  '8. Pandas 03.ipynb',
#  '0. Intro Py for Econ UT Workshop Sum 2023.pdf',
#  '4. NumPy.ipynb']

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Task 1.1: importing covid19 dataset

# %%
corona_dataset = pd.read_csv('time_series_covid19_confirmed_global.csv')
corona_dataset.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset.shape
# Out:
# (289, 1147)

# %%
corona_dataset2 = corona_dataset.copy()

# %% [markdown]
# ### Task 1.2: Delete the useless columns

# %%
corona_dataset.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
corona_dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  \
# 0        0        0        0  ...   209322  209340  209358  209362  209369
# 1        0        0        0  ...   334391  334408  334408  334427  334427
# 2        0        0        0  ...   271441  271448  271463  271469  271469
# 3        0        0        0  ...    47866   47875   47875   47875   47875
# 4        0        0        0  ...   105255  105277  105277  105277  105277
#
#    3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %% [markdown]
# ### Task 1.3: Aggregating the rows by the country

# %%
corona_dataset_aggegated = corona_dataset.groupby('Country/Region').sum(numeric_only=True)
corona_dataset_aggegated.head(15)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antarctica                 0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
# ...

# %%
corona_dataset_aggegated.shape
# Out:
# (201, 1143)

# %% [markdown]
# ### Task 1.4: Visualizing data related to countries (for example China, Italy, Spain and Iran)

# %%
plt.figure(figsize=(9,5))

corona_dataset_aggegated.loc['China'].plot(lw = 2)
corona_dataset_aggegated.loc['Italy'].plot(lw = 2)
corona_dataset_aggegated.loc['Spain'].plot(lw = 2)
corona_dataset_aggegated.loc['Iran'].plot(lw = 2)

plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(9,5))

plt.plot(range(0,1143), corona_dataset_aggegated.loc['China'], label = 'China')
plt.plot(range(0,1143), corona_dataset_aggegated.loc['Italy'], label = 'Italy')
plt.plot(range(0,1143), corona_dataset_aggegated.loc['Spain'], label = 'Spain')
plt.plot(range(0,1143), corona_dataset_aggegated.loc['Iran'], label = 'Iran')


plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.bar(range(0,1143), corona_dataset_aggegated.loc['China'], color = 'r', label = 'China')
plt.legend()
plt.grid()

plt.subplot(2,2,2)
plt.bar(range(0,1143), corona_dataset_aggegated.loc['Italy'], color = 'b', label = 'Italy')
plt.legend()
plt.grid()

plt.subplot(2,2,3)
plt.bar(range(0,1143), corona_dataset_aggegated.loc['Spain'], color = 'g', label = 'Spain')
plt.legend()
plt.grid()

plt.subplot(2,2,4)
plt.bar(range(0,1143), corona_dataset_aggegated.loc['Iran'], color = 'm', label = 'Iran')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Task 2: Calculating a good measure

# %%
corona_dataset_aggegated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggegated.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggegated.loc['Iran'][15:].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 2.1: caculating the first derivative of the curve (for China and Italy and Iran)

# %%
corona_dataset_aggegated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggegated.loc['Iran'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggegated.loc['Italy'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 2.2: find maxmimum infection rate

# %%
corona_dataset_aggegated.loc['China'].diff().max()
# Out:
# 78859.0

# %%
corona_dataset_aggegated.loc['Iran'].diff().max()
# Out:
# 50228.0

# %%
corona_dataset_aggegated.loc['Italy'].diff().max()
# Out:
# 229122.0

# %% [markdown]
# ### Task 2.3: find maximum infection rate for all of the countries.

# %%
corona_dataset_aggegated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  2/28/23  3/1/23  3/2/23  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...   209322  209340  209358
# Albania               0        0        0  ...   334391  334408  334408
# Algeria               0        0        0  ...   271441  271448  271463
# Andorra               0        0        0  ...    47866   47875   47875
# Angola                0        0        0  ...   105255  105277  105277
#
# ...

# %%
corona_dataset_aggegated.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'West Bank and Gaza', 'Winter Olympics 2022', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country/Region', length=201)

# %%
country = list(corona_dataset_aggegated.index)

# %%
len(country)
# Out:
# 201

# %%
max_infection = []

for c in country:
    max_infection.append(corona_dataset_aggegated.loc[c].diff().max())
    
corona_dataset_aggegated['max_infectation_rate'] = max_infection

# %%
corona_dataset_aggegated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  3/1/23  3/2/23  3/3/23  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...  209340  209358  209362
# Albania               0        0        0  ...  334408  334408  334427
# Algeria               0        0        0  ...  271448  271463  271469
# Andorra               0        0        0  ...   47875   47875   47875
# Angola                0        0        0  ...  105277  105277  105277
#
# ...

# %% [markdown]
# ### Task 2.4: create a new dataframe with only needed column

# %%
corona_2 = pd.DataFrame(corona_dataset_aggegated['max_infectation_rate'])

# %%
corona_2.head()
# Out:
#                 max_infectation_rate
# Country/Region
# Afghanistan                   3243.0
# Albania                       4789.0
# Algeria                       2521.0
# Andorra                       2313.0
# Angola                        5035.0

# %% [markdown]
# ### Task 3:
# - <b>Importing the WorldHappinessReport.csv dataset<b>
# - <b>selecting needed columns for our analysis <b>
# - <b>join the datasets <b>

# %% [markdown]
# ### Task 3.1 : importing the dataset

# %%
happiness_report = pd.read_csv('world-happiness-report-2021.csv')
happiness_report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# ### Task 3.2: let's drop the useless columns

# %%
happiness_report.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
useless = [
        'Regional indicator',  'Ladder score',
       'Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 
       'Ladder score in Dystopia',
       'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual'
]

# %%
happiness_report.drop(useless, axis = 1, inplace=True)

# %%
happiness_report.head()
# Out:
#   Country name  Logged GDP per capita  Social support  \
# 0      Finland                 10.775           0.954
# 1      Denmark                 10.933           0.954
# 2  Switzerland                 11.117           0.942
# 3      Iceland                 10.878           0.983
# 4  Netherlands                 10.932           0.942
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
# 3                     73.0                         0.955       0.160
# 4                     72.4                         0.913       0.175
#
#    Perceptions of corruption
# 0                      0.186
# 1                      0.179
# 2                      0.292
# 3                      0.673
# 4                      0.338

# %% [markdown]
# ### Task 3.3: changing the indices of the dataframe

# %%
happiness_report.set_index('Country name', inplace=True)

# %%
happiness_report.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                      10.775           0.954                     72.0
# Denmark                      10.933           0.954                     72.7
# Switzerland                  11.117           0.942                     74.4
# Iceland                      10.878           0.983                     73.0
# Netherlands                  10.932           0.942                     72.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# Denmark                              0.946       0.030
# Switzerland                          0.919       0.025
# Iceland                              0.955       0.160
# Netherlands                          0.913       0.175
#
#               Perceptions of corruption
# Country name
# Finland                           0.186
# Denmark                           0.179
# ...

# %% [markdown]
# ### Task 3.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
corona_2.head()
# Out:
#                 max_infectation_rate
# Country/Region
# Afghanistan                   3243.0
# Albania                       4789.0
# Algeria                       2521.0
# Andorra                       2313.0
# Angola                        5035.0

# %%
corona_2.shape
# Out:
# (201, 1)

# %% [markdown]
# #### world happiness report Dataset :

# %%
happiness_report.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                      10.775           0.954                     72.0
# Denmark                      10.933           0.954                     72.7
# Switzerland                  11.117           0.942                     74.4
# Iceland                      10.878           0.983                     73.0
# Netherlands                  10.932           0.942                     72.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# Denmark                              0.946       0.030
# Switzerland                          0.919       0.025
# Iceland                              0.955       0.160
# Netherlands                          0.913       0.175
#
#               Perceptions of corruption
# Country name
# Finland                           0.186
# Denmark                           0.179
# ...

# %%
happiness_report.shape
# Out:
# (149, 6)

# %% [markdown]
# #### Join

# %%
data = corona_2.join(happiness_report, how = 'inner')
data.head()
# Out:
#              max_infectation_rate  Logged GDP per capita  Social support  \
# Afghanistan                3243.0                  7.695           0.463
# Albania                    4789.0                  9.520           0.697
# Algeria                    2521.0                  9.342           0.802
# Argentina                139853.0                  9.962           0.898
# Armenia                    4388.0                  9.487           0.799
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                   52.493                         0.382
# Albania                       68.999                         0.785
# Algeria                       66.005                         0.480
# Argentina                     69.000                         0.828
# Armenia                       67.055                         0.825
#
#              Generosity  Perceptions of corruption
# Afghanistan      -0.102                      0.924
# ...

# %%
data.shape
# Out:
# (138, 7)

# %% [markdown]
# ## Task 4: calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1: correlation matrix

# %%
data.corr()
# Out:
#                               max_infectation_rate  Logged GDP per capita  \
# max_infectation_rate                      1.000000               0.322941
# Logged GDP per capita                     0.322941               1.000000
# Social support                            0.236806               0.798452
# Healthy life expectancy                   0.344605               0.872090
# Freedom to make life choices              0.052039               0.456510
# Generosity                               -0.037978              -0.213038
# Perceptions of corruption                -0.165432              -0.342169
#
#                               Social support  Healthy life expectancy  \
# max_infectation_rate                0.236806                 0.344605
# Logged GDP per capita               0.798452                 0.872090
# Social support                      1.000000                 0.748850
# Healthy life expectancy             0.748850                 1.000000
# ...

# %% [markdown]
# #### Correlation more than 0.5

# %%
data.corr()[data.corr()>0.5]
# Out:
#                               max_infectation_rate  Logged GDP per capita  \
# max_infectation_rate                           1.0                    NaN
# Logged GDP per capita                          NaN               1.000000
# Social support                                 NaN               0.798452
# Healthy life expectancy                        NaN               0.872090
# Freedom to make life choices                   NaN                    NaN
# Generosity                                     NaN                    NaN
# Perceptions of corruption                      NaN                    NaN
#
#                               Social support  Healthy life expectancy  \
# max_infectation_rate                     NaN                      NaN
# Logged GDP per capita               0.798452                  0.87209
# Social support                      1.000000                  0.74885
# Healthy life expectancy             0.748850                  1.00000
# ...

# %% [markdown]
# ### Task 5: Visualization of the results

# %%
x = data['Logged GDP per capita']
y = data['max_infectation_rate']

#plt.scatter(x = x, y = np.log(y))
sns.scatterplot(x = x, y = np.log(y))
# Out:
# <AxesSubplot:xlabel='Logged GDP per capita', ylabel='max_infectation_rate'>

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
plt.figure(figsize=(9,6))
sns.regplot(x = x, y = np.log(y))
plt.title('GDP per Capita VS max infectation rate', fontsize = 15, fontname = 'Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max_infectation_rate']

sns.scatterplot(x = x, y = np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max_infectation_rate'>

# %%
plt.figure(figsize=(9,6))
sns.regplot(x = x, y = np.log(y))
plt.title('Social support VS max infectation rate', fontsize = 15, fontname = 'Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max_infectation_rate']

sns.scatterplot(x = x, y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x = x, y = np.log(y))
plt.title('Healthy life expectancy VS max infectation rate', fontsize = 15, fontname = 'Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max_infectation_rate']

sns.scatterplot(x = x, y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x = x, y = np.log(y))
plt.title('Freedom to make life choices VS max infectation rate', fontsize = 15, fontname = 'Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.5: Plotting Perceptions of corruption vs maximum Infection rate

# %%
data.columns
# Out:
# Index(['max_infectation_rate', 'Logged GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
x = data['Perceptions of corruption']
y = data['max_infectation_rate']

sns.scatterplot(x = x, y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x = x, y = np.log(y))
plt.title('Perceptions of corruption VS max infectation rate', fontsize = 15, fontname = 'Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.5: Plotting Generosity vs maximum Infection rate

# %%
data.columns
# Out:
# Index(['max_infectation_rate', 'Logged GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
x = data['Generosity']
y = data['max_infectation_rate']

sns.scatterplot(x = x, y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x = x, y = np.log(y))
plt.title('Generosity VS max infectation rate', fontsize = 15, fontname = 'Times New Roman')

plt.grid()
plt.show()

# %%
happiness_report_beta = pd.read_csv('world-happiness-report-2021.csv')
happiness_report_beta.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
useless = [
        'Ladder score',
       'Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 
       'Ladder score in Dystopia',
       'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption',
       'Dystopia + residual'
]
happiness_report_beta.drop(useless, axis = 1, inplace=True)

# %%
happiness_report_beta.head()
# Out:
#   Country name Regional indicator  Logged GDP per capita  Social support  \
# 0      Finland     Western Europe                 10.775           0.954
# 1      Denmark     Western Europe                 10.933           0.954
# 2  Switzerland     Western Europe                 11.117           0.942
# 3      Iceland     Western Europe                 10.878           0.983
# 4  Netherlands     Western Europe                 10.932           0.942
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
# 3                     73.0                         0.955       0.160
# 4                     72.4                         0.913       0.175
#
#    Perceptions of corruption
# 0                      0.186
# 1                      0.179
# ...

# %%
happiness_report_beta['Regional indicator'].unique()
# Out:
# array(['Western Europe', 'North America and ANZ',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
happiness_report_beta.groupby('Regional indicator').mean(numeric_only=True)
# Out:
#                                     Logged GDP per capita  Social support  \
# Regional indicator
# Central and Eastern Europe                      10.109059        0.887412
# Commonwealth of Independent States               9.401833        0.872500
# East Asia                                       10.367667        0.860500
# Latin America and Caribbean                      9.370000        0.839500
# Middle East and North Africa                     9.666118        0.797647
# North America and ANZ                           10.809500        0.933500
# South Asia                                       8.682571        0.703429
# Southeast Asia                                   9.421444        0.820333
# Sub-Saharan Africa                               8.075194        0.696750
# Western Europe                                  10.822714        0.914476
#
#                                     Healthy life expectancy  \
# Regional indicator
# ...

# %%
happiness_report_beta.groupby('Regional indicator').mean(numeric_only=True).sort_values('Healthy life expectancy', ascending=False)
# Out:
#                                     Logged GDP per capita  Social support  \
# Regional indicator
# Western Europe                                  10.822714        0.914476
# North America and ANZ                           10.809500        0.933500
# East Asia                                       10.367667        0.860500
# Central and Eastern Europe                      10.109059        0.887412
# Latin America and Caribbean                      9.370000        0.839500
# Middle East and North Africa                     9.666118        0.797647
# Commonwealth of Independent States               9.401833        0.872500
# Southeast Asia                                   9.421444        0.820333
# South Asia                                       8.682571        0.703429
# Sub-Saharan Africa                               8.075194        0.696750
#
#                                     Healthy life expectancy  \
# Regional indicator
# ...

# %%
happiness_report_beta.groupby('Regional indicator').get_group('Middle East and North Africa')
# Out:
#                 Country name            Regional indicator  \
# 11                    Israel  Middle East and North Africa
# 21                   Bahrain  Middle East and North Africa
# 24      United Arab Emirates  Middle East and North Africa
# 25              Saudi Arabia  Middle East and North Africa
# 46                    Kuwait  Middle East and North Africa
# 79                     Libya  Middle East and North Africa
# 103                   Turkey  Middle East and North Africa
# 105                  Morocco  Middle East and North Africa
# 108                  Algeria  Middle East and North Africa
# 110                     Iraq  Middle East and North Africa
# 117                     Iran  Middle East and North Africa
# 121                  Tunisia  Middle East and North Africa
# 122                  Lebanon  Middle East and North Africa
# 124  Palestinian Territories  Middle East and North Africa
# 126                   Jordan  Middle East and North Africa
# ...
